# %%
import requests
import pandas as pd

# %%
url='http://ergast.com/api/f1/2022/22/results.json'
r=requests.get(url)
json=r.json()

# %%
r=requests.get(url)
json=r.json()

# %%
json.keys()
# Out:
# dict_keys(['MRData'])

# %%
json
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2022/22/results.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '20',
#   'RaceTable': {'season': '2022',
#    'round': '22',
#    'Races': [{'season': '2022',
#      'round': '22',
#      'url': 'http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Grand_Prix',
#      'raceName': 'Abu Dhabi Grand Prix',
#      'Circuit': {'circuitId': 'yas_marina',
#       'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#       'circuitName': 'Yas Marina Circuit',
#       'Location': {'lat': '24.4672',
#        'long': '54.6031',
#        'locality': 'Abu Dhabi',
#        'country': 'UAE'}},
#      'date': '2022-11-20',
#      'time': '13:00:00Z',
#      'Results': [{'number': '1',
#        'position': '1',
#        'positionText': '1',
#        'points': '25',
#        'Driver': {'driverId': 'max_verstappen',
#         'permanentNumber': '33',
#         'code': 'VER',
# ...

# %%
json.keys()
# Out:
# dict_keys(['MRData'])

# %%
json['MRData'].keys()
# Out:
# dict_keys(['xmlns', 'series', 'url', 'limit', 'offset', 'total', 'RaceTable'])

# %%
results=pd.DataFrame(json['MRData']['RaceTable']['Races'][0]['Results'])

# %%
results.head()
# Out:
#   number position positionText points          Driver  \
# 0      1        1            1     25  max_verstappen
# 1     16        2            2     18         leclerc
# 2     11        3            3     15           perez
# 3     55        4            4     12           sainz
# 4     63        5            5     10         russell
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'red_bull', 'url': 'http://e...    1   58  Finished
# 1  {'constructorId': 'ferrari', 'url': 'http://en...    3   58  Finished
# 2  {'constructorId': 'red_bull', 'url': 'http://e...    2   58  Finished
# 3  {'constructorId': 'ferrari', 'url': 'http://en...    4   58  Finished
# 4  {'constructorId': 'mercedes', 'url': 'http://e...    6   58  Finished
#
#                                            Time FastestLap
# 0  {'millis': '5265914', 'time': '1:27:45.914'}   1:29.392
# 1       {'millis': '5274685', 'time': '+8.771'}   1:29.719
# ...

# %%
for i in range(len(results['Constructor'])):
    print(results['Constructor'][i]['url'])
# Out:
# http://en.wikipedia.org/wiki/Red_Bull_Racing
# http://en.wikipedia.org/wiki/Scuderia_Ferrari
# http://en.wikipedia.org/wiki/Red_Bull_Racing
# http://en.wikipedia.org/wiki/Scuderia_Ferrari
# http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One
# http://en.wikipedia.org/wiki/McLaren
# http://en.wikipedia.org/wiki/Alpine_F1_Team
# http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One
# http://en.wikipedia.org/wiki/McLaren
# http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One
# http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One
# http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering
# http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One
# http://en.wikipedia.org/wiki/Haas_F1_Team
# http://en.wikipedia.org/wiki/Haas_F1_Team
# http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One
# http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering
# ...

# %%
for i in range(len(results['Time'])):
    print(results['Time'][i]['time'])
# Out:
# 1:27:45.914
# +8.771
# +10.093
# +24.892
# +35.888
# +56.234
# +57.240
# +1:16.931
# +1:23.268
# +1:23.898
# +1:29.371
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14924\1884596053.py in <module>
#       1 for i in range(len(results['Time'])):
# ----> 2     print(results['Time'][i]['time'])
#
# TypeError: 'float' object is not subscriptable

# %%
for i in range(len(results['FastestLap'])):
    print(results['FastestLap'][i]['Time'])
# Out:
# {'time': '1:29.392'}
# {'time': '1:29.719'}
# {'time': '1:28.972'}
# {'time': '1:28.879'}
# {'time': '1:28.836'}
# {'time': '1:28.391'}
# {'time': '1:29.333'}
# {'time': '1:29.620'}
# {'time': '1:30.785'}
# {'time': '1:30.312'}
# {'time': '1:29.489'}
# {'time': '1:29.600'}
# {'time': '1:29.939'}
# {'time': '1:31.081'}
# {'time': '1:30.352'}
# {'time': '1:29.833'}
# {'time': '1:31.158'}
# {'time': '1:29.788'}
# {'time': '1:30.309'}
# {'time': '1:30.579'}

# %%
for i in range(len(results['Driver'])):
    print(results['Driver'][i]['driverId'])
# Out:
# max_verstappen
# leclerc
# perez
# sainz
# russell
# norris
# ocon
# stroll
# ricciardo
# vettel
# tsunoda
# zhou
# albon
# gasly
# bottas
# mick_schumacher
# kevin_magnussen
# hamilton
# latifi
# alonso

# %%
results['Driver'].apply(lambda x:x['driverId'])
# Out:
# 0      max_verstappen
# 1             leclerc
# 2               perez
# 3               sainz
# 4             russell
# 5              norris
# 6                ocon
# 7              stroll
# 8           ricciardo
# 9              vettel
# 10            tsunoda
# 11               zhou
# 12              albon
# 13              gasly
# 14             bottas
# 15    mick_schumacher
# 16    kevin_magnussen
# 17           hamilton
# 18             latifi
# 19             alonso
# Name: Driver, dtype: object

# %%
results['Constructor']=results['Cosntructor'].apply(lambda x:x['constructorId'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cosntructor'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
results['Driver']=results['Driver'].apply(lambda x: x['driverId'])

# %% [raw]
# results

# %%
results
# Out:
#    number position positionText points           Driver  \
# 0       1        1            1     25   max_verstappen
# 1      16        2            2     18          leclerc
# 2      11        3            3     15            perez
# 3      55        4            4     12            sainz
# 4      63        5            5     10          russell
# 5       4        6            6      9           norris
# 6      31        7            7      6             ocon
# 7      18        8            8      4           stroll
# 8       3        9            9      2        ricciardo
# 9       5       10           10      1           vettel
# 10     22       11           11      0          tsunoda
# 11     24       12           12      0             zhou
# 12     23       13           13      0            albon
# 13     10       14           14      0            gasly
# 14     77       15           15      0           bottas
# 15     47       16           16      0  mick_schumacher
# ...

# %%
results['Time']=results['Time'].apply(lambda x: x['time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14924\789801560.py in <module>
# ----> 1 results['Time']=results['Time'].apply(lambda x: x['time'])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# ...

# %%
results['FastestLap']=results['FastestLap'].apply(lambda x: x['Time']['time'])

# %%
results
# Out:
#    number position positionText points           Driver  \
# 0       1        1            1     25   max_verstappen
# 1      16        2            2     18          leclerc
# 2      11        3            3     15            perez
# 3      55        4            4     12            sainz
# 4      63        5            5     10          russell
# 5       4        6            6      9           norris
# 6      31        7            7      6             ocon
# 7      18        8            8      4           stroll
# 8       3        9            9      2        ricciardo
# 9       5       10           10      1           vettel
# 10     22       11           11      0          tsunoda
# 11     24       12           12      0             zhou
# 12     23       13           13      0            albon
# 13     10       14           14      0            gasly
# 14     77       15           15      0           bottas
# 15     47       16           16      0  mick_schumacher
# ...

# %%
¿Cual es el equipo favorito en cada circuito?
¿Cuantos pilotos ha patrocinado cada equipo?
¿Cual es el piloto que ha ganado mas carreras?
¿Cual es el menor tiempo?
¿Relacion entre la posicion de salida y posicion de llegada?
¿Cual es la probabilidad de ganar una carrera por piloto?
¿Que probabilidad tiene el piloto de abandondar la carrera?
¿Que piloto ha estado mas temporadas?

# %%
'Todas las carreras del 2022'
results.head()
# Out:
#   number position positionText points          Driver  \
# 0      1        1            1     25  max_verstappen
# 1     16        2            2     18         leclerc
# 2     11        3            3     15           perez
# 3     55        4            4     12           sainz
# 4     63        5            5     10         russell
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'red_bull', 'url': 'http://e...    1   58  Finished
# 1  {'constructorId': 'ferrari', 'url': 'http://en...    3   58  Finished
# 2  {'constructorId': 'red_bull', 'url': 'http://e...    2   58  Finished
# 3  {'constructorId': 'ferrari', 'url': 'http://en...    4   58  Finished
# 4  {'constructorId': 'mercedes', 'url': 'http://e...    6   58  Finished
#
#                                            Time FastestLap
# 0  {'millis': '5265914', 'time': '1:27:45.914'}   1:29.392
# 1       {'millis': '5274685', 'time': '+8.771'}   1:29.719
# ...

# %%
url='http://ergast.com/api/f1/2022.json'
r=requests.get(url)
json=r.json()

# %%
json
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2022.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'RaceTable': {'season': '2022',
#    'Races': [{'season': '2022',
#      'round': '1',
#      'url': 'http://en.wikipedia.org/wiki/2022_Bahrain_Grand_Prix',
#      'raceName': 'Bahrain Grand Prix',
#      'Circuit': {'circuitId': 'bahrain',
#       'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#       'circuitName': 'Bahrain International Circuit',
#       'Location': {'lat': '26.0325',
#        'long': '50.5106',
#        'locality': 'Sakhir',
#        'country': 'Bahrain'}},
#      'date': '2022-03-20',
#      'time': '15:00:00Z',
#      'FirstPractice': {'date': '2022-03-18', 'time': '12:00:00Z'},
#      'SecondPractice': {'date': '2022-03-18', 'time': '15:00:00Z'},
#      'ThirdPractice': {'date': '2022-03-19', 'time': '12:00:00Z'},
# ...

# %%
Res22=pd.DataFrame(json)

# %%
Res22.head()
# Out:
#                                                       MRData
# RaceTable  {'season': '2022', 'Races': [{'season': '2022'...
# limit                                                     30
# offset                                                     0
# series                                                    f1
# total                                                     22

# %% [markdown]
# #
